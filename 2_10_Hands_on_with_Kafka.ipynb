# %% [markdown]
# <a href="https://colab.research.google.com/github/nat35im/5m-data-2.10-distributed-stream/blob/main/2_10_Hands_on_with_Kafka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-on with Kafka
#
# ![kafka](https://images.contentful.com/gt6dp23g0g38/53UO4964r0e7kRVm0mcUUZ/f6f6d7b1b90e8e88a5be0d1845bdf950/what_is_kafka_and_how_does_it_work.png)

# %% [markdown]
# ## Installing Kafka Python Client
#
# First, we'll need to install Kafka Python client `kafka-python` to consume messages from a Kafka cluster.

# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.6-py2.py3-none-any.whl.metadata (9.0 kB)
# Downloading kafka_python-2.0.6-py2.py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.6

# %%
import json
from kafka import KafkaConsumer, TopicPartition

# %% [markdown]
# First, we'll instantiate the consumer.
#
# Our data was serialized in JSON during publishing, hence we'll need to deserialize as JSON when consuming. In actual production, it is recommended to use the binary format that we've learnt, such as Avro.

# %%
consumer = KafkaConsumer(
  bootstrap_servers=['brave-fish-11463-us1-kafka.upstash.io:9092'],
  sasl_mechanism='SCRAM-SHA-256',
  security_protocol='SASL_SSL',
  sasl_plain_username='YnJhdmUtZmlzaC0xMTQ2MyQSvwXBuLOQsV1W7YffuC8cDaZcA3fKQwakMhnQGgg',
  sasl_plain_password='MDUxNjc4YzEtYzYxNy00NTE1LWEwNWYtMDBhODRlZmE0OGJm',
  auto_offset_reset='earliest',
  value_deserializer = lambda v: json.loads(v.decode('ascii')),
  key_deserializer = lambda v: json.loads(v.decode('ascii')),
)
# Out:
# WARNING:kafka.conn:DNS lookup failed for brave-fish-11463-us1-kafka.upstash.io:9092, exception was [Errno -2] Name or service not known. Is your advertised.listeners (called advertised.host.name before Kafka 9) correct and resolvable?
# ERROR:kafka.conn:DNS lookup failed for brave-fish-11463-us1-kafka.upstash.io:9092 (0)
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# <ipython-input-4-8fac7cb50aaf> in <cell line: 0>()
# ----> 1 consumer = KafkaConsumer(
#       2   bootstrap_servers=['brave-fish-11463-us1-kafka.upstash.io:9092'],
#       3   sasl_mechanism='SCRAM-SHA-256',
#       4   security_protocol='SASL_SSL',
#       5   sasl_plain_username='YnJhdmUtZmlzaC0xMTQ2MyQSvwXBuLOQsV1W7YffuC8cDaZcA3fKQwakMhnQGgg',
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in __init__(self, *topics, **configs)
#     356                         str(self.config['api_version']), str_version)
#     357
# --> 358         self._client = self.config['kafka_client'](metrics=self._metrics, **self.config)
#     359
#     360         # Get auto-discovered version from client if necessary
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in __init__(self, **configs)
#     238         # Check Broker Version if not set explicitly
#     239         if self.config['api_version'] is None:
# --> 240             self.config['api_version'] = self.check_version()
#     241
#     242     def _init_wakeup_socketpair(self):
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     944             if try_node is None:
#     945                 self._lock.release()
# --> 946                 raise Errors.NoBrokersAvailable()
#     947             if not self._init_connect(try_node):
#     948                 if try_node == node_id:
#
# NoBrokersAvailable: NoBrokersAvailable

# %% [markdown]
# We set the offset for the consumer to be `earliest` to get the earliest order (message).
#
# List the available topics:

# %%
consumer.topics()
# Out:
# {'pizza-orders'}

# %% [markdown]
# Let's assume we are the owners of a pizza delivery chain, and we'd like to push the orders to Apache Kafka as they come in.
#
# We have a topic consisting of pizza orders, which contains the Order ID, Order Details (pizzas and toppings), client's Name, Address, Phone Number, the Shop Name, Total Cost and Timestamp.
#
# There is only one partition for the topic. First, let's subscribe to the topic:

# %%
topic_name = "pizza-orders"

# %%
consumer.subscribe(topics=[topic_name])
consumer.subscription()
# Out:
# {'pizza-orders'}

# %% [markdown]
# We can then start reading the events, let's read and (pretty) print the first 5:

# %%
from pprint import pprint

# %%
for ix, message in enumerate(consumer, start=1):
    print("%d:%d: k=%s" % (message.partition,
                           message.offset,
                           message.key))
    pprint(message.value)
    print()
    if ix == 5:
        break
# Out:
# 0:0: k={'shop': 'Circular Pi Pizzeria'}
# {'address': '06867 Sean Spring Suite 858\nHaleyshire, LA 64405',
#  'cost': 16.66,
#  'id': 1,
#  'name': 'Morgan Morgan',
#  'phoneNumber': '+1-511-717-0366',
#  'pizzas': [{'additionalToppings': ['🌶️ hot pepper'], 'pizzaName': 'Salami'},
#             {'additionalToppings': ['🧄 garlic', '🍅 tomato', '🥚 egg'],
#              'pizzaName': 'Diavola'}],
#  'shop': 'Circular Pi Pizzeria',
#  'timestamp': 1696869293351}
#
# 0:1: k={'shop': 'Mammamia Pizza'}
# {'address': '5781 John Fords\nNorth Raymondfurt, WI 48507',
#  'cost': 3.52,
#  'id': 2,
#  'name': 'Jorge Henry',
#  'phoneNumber': '651.622.1464x789',
#  'pizzas': [{'additionalToppings': ['🫑 green peppers', '🍅 tomato'],
#              'pizzaName': 'Diavola'},
#             {'additionalToppings': [], 'pizzaName': 'Salami'},
#             {'additionalToppings': [], 'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🥓 bacon', '🧄 garlic'],
#              'pizzaName': 'Diavola'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1696869294355}
#
# 0:2: k={'shop': 'Mammamia Pizza'}
# {'address': '42486 Kelly Trafficway\nNew Teresaland, GU 26156',
#  'cost': 13.53,
#  'id': 3,
#  'name': 'Sarah Brock',
#  'phoneNumber': '001-939-282-5548x708',
#  'pizzas': [{'additionalToppings': ['🥓 bacon', '🧅 onion'],
#              'pizzaName': 'Mari & Monti'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1696869295357}
#
# 0:3: k={'shop': 'Marios Pizza'}
# {'address': '37881 Clayton Corner Apt. 096\nJohnburgh, AS 95223',
#  'cost': 5.59,
#  'id': 4,
#  'name': 'Brendan Lawrence',
#  'phoneNumber': '476.944.1630x8884',
#  'pizzas': [{'additionalToppings': ['🐟 tuna'], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': [], 'pizzaName': 'Diavola'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1696869297361}
#
# 0:4: k={'shop': 'Its-a me! Mario Pizza!'}
# {'address': '86725 Dillon Valley\nRiveraburgh, IN 27927',
#  'cost': 13.64,
#  'id': 5,
#  'name': 'Chad Michael',
#  'phoneNumber': '001-704-948-3209x946',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Marinara'},
#             {'additionalToppings': ['🧄 garlic'], 'pizzaName': 'Peperoni'}],
#  'shop': 'Its-a me! Mario Pizza!',
#  'timestamp': 1696869299365}

# %% [markdown]
# Now, continue printing the next 5 events, notice the offset number and order id:

# %%
for ix, message in enumerate(consumer, start=1):
    print("%d:%d: k=%s" % (message.partition,
                           message.offset,
                           message.key))
    pprint(message.value)
    print()
    if ix == 5:
        break
# Out:
# 0:5: k={'shop': 'Mammamia Pizza'}
# {'address': '4874 Wright Lock\nNorth Leonardton, AZ 12821',
#  'cost': 42.26,
#  'id': 6,
#  'name': 'Joseph Lowe',
#  'phoneNumber': '743.698.6156x6633',
#  'pizzas': [{'additionalToppings': ['🫒 olives'], 'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🫑 green peppers'], 'pizzaName': 'Salami'},
#             {'additionalToppings': ['🫑 green peppers', '🍍 pineapple'],
#              'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🍓 strawberry'], 'pizzaName': 'Salami'},
#             {'additionalToppings': ['🫒 olives'], 'pizzaName': 'Marinara'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1696869300368}
#
# 0:6: k={'shop': 'Luigis Pizza'}
# {'address': '9167 Thomas Mission Apt. 588\nPort Sarahhaven, WI 31469',
#  'cost': 26.65,
#  'id': 7,
#  'name': 'Andrea Robbins',
#  'phoneNumber': '242.719.1159',
#  'pizzas': [{'additionalToppings': ['🧀 blue cheese'], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🍌 banana', '🍍 pineapple', '🍍 pineapple'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🫑 green peppers'],
#              'pizzaName': 'Mari & Monti'}],
#  'shop': 'Luigis Pizza',
#  'timestamp': 1696869302371}
#
# 0:7: k={'shop': 'Marios Pizza'}
# {'address': '562 Anthony Village Apt. 809\nNorth Ronald, SD 61716',
#  'cost': 26.43,
#  'id': 8,
#  'name': 'Allison Reed',
#  'phoneNumber': '(803)702-3145',
#  'pizzas': [{'additionalToppings': ['🍓 strawberry'], 'pizzaName': 'Marinara'},
#             {'additionalToppings': ['🥓 bacon', '🧀 blue cheese'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🥓 bacon', '🧄 garlic', '🥚 egg'],
#              'pizzaName': 'Diavola'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1696869303373}
#
# 0:8: k={'shop': 'Marios Pizza'}
# {'address': '714 West Rest Apt. 183\nHolderview, KS 15207',
#  'cost': 37.98,
#  'id': 9,
#  'name': 'Stephanie Riley',
#  'phoneNumber': '001-469-306-4599',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Salami'},
#             {'additionalToppings': ['🧀 blue cheese', '🍌 banana'],
#              'pizzaName': 'Diavola'},
#             {'additionalToppings': ['🥓 bacon', '🥚 egg', '🧀 blue cheese'],
#              'pizzaName': 'Marinara'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1696869305377}
#
# 0:9: k={'shop': 'Marios Pizza'}
# {'address': '806 Anthony Canyon\nMeghanview, SC 93127',
#  'cost': 42.94,
#  'id': 10,
#  'name': 'Stanley Jenkins',
#  'phoneNumber': '647-754-1719',
#  'pizzas': [{'additionalToppings': ['🥚 egg', '🍍 pineapple'],
#              'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🍓 strawberry',
#                                     '🍅 tomato',
#                                     '🌶️ hot pepper'],
#              'pizzaName': 'Marinara'},
#             {'additionalToppings': ['🍍 pineapple'], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🍍 pineapple', '🫑 green peppers'],
#              'pizzaName': 'Marinara'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1696869307381}

# %% [markdown]
# This is the full code to publish an example order:
#
# ```python
# from kafka import KafkaProducer
#
# producer = KafkaProducer(
#   bootstrap_servers=['brave-fish-11463-us1-kafka.upstash.io:9092'],
#   sasl_mechanism='SCRAM-SHA-256',
#   security_protocol='SASL_SSL',
#   sasl_plain_username='YnJhdmUtZmlzaC0xMTQ2MyQSvwXBuLOQsV1W7YffuC8cDaZcA3fKQwakMhnQGgg',
#   sasl_plain_password='MDUxNjc4YzEtYzYxNy00NTE1LWEwNWYtMDBhODRlZmE0OGJm',
#   value_serializer=lambda v: json.dumps(v).encode('ascii'),
#   key_serializer=lambda v: json.dumps(v).encode('ascii')
# )
#
# message = {'address': '8697 Anthony Valley\nPort Kellymouth, FL 64221',
#  'id': 10,
#  'name': 'Patricia Castaneda',
#  'phoneNumber': '328-798-9970x51560',
#  'pizzas': [{'additionalToppings': ['🍅 tomato'], 'pizzaName': 'Mari & Monti'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1696609343719}
#
# key = {'shop': 'Mammamia Pizza'}
#
# producer.send(topic_name, key=key, value=message)
# ```
